# %%
from dataclasses import dataclass
from typing import *

# %%
def remove_linebreaks(lines):
    return [line.rstrip("\n") for line in lines]


def get_lines_that_start_with_asterisk_and_space(lines):
    return [line.lstrip("* ") for line in lines if line[:2] == "* "]


def remove(lines, string_to_remove):
    return [line.replace(string_to_remove, "") for line in lines]

# %%
def get_lines():
    filename = "docs/about/credits.rst"

    with open(filename, "r") as f:
        lines = f.readlines()

    lines = remove_linebreaks(lines)
    lines = get_lines_that_start_with_asterisk_and_space(lines)[
        3:
    ]  # coordination committee
    lines = remove(lines, ":user:")
    lines = remove(lines, ":orcid:")
    lines = remove(lines, "`")
    lines = remove(lines, ">")
    lines = remove(lines, ")")

    return lines

# %%
indent = 4 * " "


@dataclass
class Contributor:
    github_username: Optional[str] = None
    given_name: Optional[str] = None
    family_name: Optional[str] = None
    orcid: Optional[str] = None
    affiliation: Optional[str] = None
    on_coordinating_committee: bool = False

    def __str__(self):

        s = "Contributor("

        return (
            f"Contributor("
            f"github_username={self.github_username!r}, "
            f"given_name={self.given_name!r}, "
            f"family_name={self.family_name!r}, "
            f"orcid={self.orcid!r}, "
            f"affiliation={self.affiliation!r} "
            f")"
        )

    def codemetafy(self):

        lines = []

        if not any([self.given_name, self.family_name]):
            return ""

        lines.append(3 * indent + '"@type": "Person"')

        if self.orcid:
            lines.append(3 * indent + f'"@id": "https://orcid.org/{self.orcid}"')

        if self.given_name:
            lines.append(3 * indent + f'"givenName": "{self.given_name}"')

        if self.family_name:
            lines.append(3 * indent + f'"familyName": "{self.family_name}"')

        return 2 * indent + "{\n" + ",\n".join(lines) + "\n" + 2 * indent + "},"

# %%
def get_contributor(line: str):

    if r" <http" in line:
        line = line.split(r" <http")[0]

    if " " not in line:
        return Contributor(github_username=line)

    kwargs = {}

    if "(" in line:
        line, kwargs["orcid"] = line.split(" (")
    else:
        kwargs["orcid"] = None

    if "<" in line:
        line, kwargs["github_username"] = line.split(" <")
    else:
        kwargs["github_username"] = None

    full_name = line
    name_components = full_name.split()
    kwargs["family_name"] = name_components[-1]
    kwargs["given_name"] = " ".join(name_components[:-1])

    return Contributor(**kwargs)

# %%
def get_contributor_list():
    lines = get_lines()

    contributors = [get_contributor(line) for line in lines]

    contributors = sorted(
        contributors, key=lambda x: x.family_name if x.family_name else ""
    )

    for contributor in contributors:
        print(contributor.codemetafy())

    return contributors

# %%
get_contributor_list()
# Out:
#         {
#             "@type": "Person",
#             "familyName": "Andrew"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-8644-8118",
#             "givenName": "Christoper",
#             "familyName": "Arran"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-7381-1996",
#             "givenName": "Haman",
#             "familyName": "Bagherianlemraski"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Jasper",
#             "familyName": "Beckers"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Manas",
#             "familyName": "Bedmutha"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Justin",
#             "familyName": "Bergeron"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Ludovico",
#             "familyName": "Bessi"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Riley",
#             "familyName": "Britten"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Shane",
#             "familyName": "Brown"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Khalil",
#             "familyName": "Bryant"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Sean",
#             "familyName": "Carroll"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Sean",
#             "familyName": "Chambers"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Ankur",
#             "familyName": "Chattopadhyay"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Apoorv",
#             "familyName": "Choubey"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Jacob",
#             "familyName": "Deal"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-1984-7303",
#             "givenName": "Fionnlagh Mackenzie",
#             "familyName": "Dover"
#         },
#         {
#             "@type": "Person",
#             "givenName": "David",
#             "familyName": "Drozdov"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-8676-1710",
#             "givenName": "Tiger",
#             "familyName": "Du"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Leah",
#             "familyName": "Einhorn"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-6079-8307",
#             "givenName": "Erik",
#             "familyName": "Everson"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Thomas",
#             "familyName": "Fan"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-0223-7004",
#             "givenName": "Samaiyah I.",
#             "familyName": "Farid"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Michael",
#             "familyName": "Fischer"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-5308-6870",
#             "givenName": "Bryan",
#             "familyName": "Foo"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Rajagopalan",
#             "familyName": "Gangadharan"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Brian",
#             "familyName": "Goodall"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Marco",
#             "familyName": "Gorelli"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Graham",
#             "familyName": "Goudeau"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Silvina",
#             "familyName": "Guidoni"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-2160-7288",
#             "givenName": "Colby",
#             "familyName": "Haggerty"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Raymon Skjørten",
#             "familyName": "Hansen"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-5050-6606",
#             "givenName": "Peter",
#             "familyName": "Heuer"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-1073-6383",
#             "givenName": "Julien",
#             "familyName": "Hillairet"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Chris",
#             "familyName": "Hoang"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Poh Zi",
#             "familyName": "How"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-4237-2211",
#             "givenName": "Yi-Min",
#             "familyName": "Huang"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Nabil",
#             "familyName": "Humphrey"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Maria",
#             "familyName": "Isupova"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-2892-6924",
#             "givenName": "Alexis",
#             "familyName": "Jeandet"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Elliot",
#             "familyName": "Johnson"
#         },
#         {
#             "@type": "Person",
#             "givenName": "James",
#             "familyName": "Kent"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-6849-3612",
#             "givenName": "Pawel",
#             "familyName": "Kozlowski"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Siddharth",
#             "familyName": "Kulshrestha"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Piotr",
#             "familyName": "Kuszaj"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-1192-2057",
#             "givenName": "Alf",
#             "familyName": "Köhn-Seemann"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-7757-5879",
#             "givenName": "Samuel",
#             "familyName": "Langendorf"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Anna",
#             "familyName": "Lanteri"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Terrance Takho",
#             "familyName": "Lee"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-5270-7487",
#             "givenName": "Drew",
#             "familyName": "Leonard"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Nicolas",
#             "familyName": "Lequette"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-0079-4114",
#             "givenName": "Pey Lian",
#             "familyName": "Lim"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Aditya",
#             "familyName": "Magarde"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Ritiek",
#             "familyName": "Malhotra"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Joao Victor",
#             "familyName": "Martinelli"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-5394-9445",
#             "givenName": "Isaias",
#             "familyName": "McHardy"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Dhawal",
#             "familyName": "Modi"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-0762-3708",
#             "givenName": "Kevin",
#             "familyName": "Montes"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-4217-4642",
#             "givenName": "Stuart",
#             "familyName": "Mumford"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Joshua",
#             "familyName": "Munn"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Leo",
#             "familyName": "Murphy"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-6628-8033",
#             "givenName": "Nick",
#             "familyName": "Murphy"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Suzanne",
#             "familyName": "Nie"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Mahima",
#             "familyName": "Pannala"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-0602-8381",
#             "givenName": "Tulasi",
#             "familyName": "Parashar"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Neil",
#             "familyName": "Patel"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Francisco Silva",
#             "familyName": "Pavon"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Jakub",
#             "familyName": "Polak"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Roberto Díaz",
#             "familyName": "Pérez"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-8358-0482",
#             "givenName": "Ramiz",
#             "familyName": "Qudsi"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Raajit",
#             "familyName": "Raj"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-4914-6612",
#             "givenName": "Vishwas",
#             "familyName": "Rajashekar"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Afzal",
#             "familyName": "Rao"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-3056-6334",
#             "givenName": "Steve",
#             "familyName": "Richardson"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Diego A. Diaz",
#             "familyName": "Riega"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Armando",
#             "familyName": "Salcido"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-5598-046X",
#             "givenName": "Antonia",
#             "familyName": "Savcheva"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-9258-4490",
#             "givenName": "Chengcai",
#             "familyName": "Shen"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Andrew",
#             "familyName": "Sheng"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Dawa Nurbu",
#             "familyName": "Sherpa"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0003-3530-7910",
#             "givenName": "Luciano",
#             "familyName": "Silvestri"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Angad",
#             "familyName": "Singh"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Ankit",
#             "familyName": "Singh"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-3713-6337",
#             "givenName": "Brigitta",
#             "familyName": "Sipőcz"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Cody",
#             "familyName": "Skinner"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Nikita",
#             "familyName": "Smirnov"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-1365-1908",
#             "givenName": "David",
#             "familyName": "Stansby"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0001-6291-8843",
#             "givenName": "Dominik",
#             "familyName": "Stańczak"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Tomás",
#             "familyName": "Stinson"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Antoine",
#             "familyName": "Tavant"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Thomas",
#             "familyName": "Ulrich"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Thomas",
#             "familyName": "Varnish"
#         },
#         {
#             "@type": "Person",
#             "@id": "https://orcid.org/0000-0002-8335-1441",
#             "givenName": "Tien",
#             "familyName": "Vo"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Sixue",
#             "familyName": "Xu"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Chun Hei",
#             "familyName": "Yip"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Reynaldo Rojas",
#             "familyName": "Zelaya"
#         },
#         {
#             "@type": "Person",
#             "givenName": "Carol",
#             "familyName": "Zhang"
#         },
# [Contributor(github_username='BH4', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='cclauss', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='flaixman', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='itsraashi', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='lgoenner', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='@nrb1324', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='seanjunheng2', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='siddharthk07', given_name=None, family_name=None, orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='sandshrew118', given_name='', family_name='Andrew', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='ChrisArran', given_name='Christoper', family_name='Arran', orcid='0000-0002-8644-8118', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='haman80', given_name='Haman', family_name='Bagherianlemraski', orcid='0000-0001-7381-1996', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jasperbeckers', given_name='Jasper', family_name='Beckers', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='manasbedmutha98', given_name='Manas', family_name='Bedmutha', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Justin-Bergeron', given_name='Justin', family_name='Bergeron', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='ludoro', given_name='Ludovico', family_name='Bessi', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='riley-britten', given_name='Riley', family_name='Britten', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Sjbrownian', given_name='Shane', family_name='Brown', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='KhalilBryant', given_name='Khalil', family_name='Bryant', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='seanwilliamcarroll', given_name='Sean', family_name='Carroll', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='schambers', given_name='Sean', family_name='Chambers', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='chttrjeankr', given_name='Ankur', family_name='Chattopadhyay', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='apooravc', given_name='Apoorv', family_name='Choubey', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Jac0bDeal', given_name='Jacob', family_name='Deal', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='FinMacDov', given_name='Fionnlagh Mackenzie', family_name='Dover', orcid='0000-0002-1984-7303', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='davemus', given_name='David', family_name='Drozdov', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Tiger-Du', given_name='Tiger', family_name='Du', orcid='0000-0002-8676-1710', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='leahein', given_name='Leah', family_name='Einhorn', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='rocco8773', given_name='Erik', family_name='Everson', orcid='0000-0001-6079-8307', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='thomasjpfan', given_name='Thomas', family_name='Fan', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='samaiyahfarid', given_name='Samaiyah I.', family_name='Farid', orcid='0000-0003-0223-7004', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username=None, given_name='Michael', family_name='Fischer', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='bryancfoo', given_name='Bryan', family_name='Foo', orcid='0000-0001-5308-6870', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='RAJAGOPALAN-GANGADHARAN', given_name='Rajagopalan', family_name='Gangadharan', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='goodab', given_name='Brian', family_name='Goodall', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='MarcoGorelli', given_name='Marco', family_name='Gorelli', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='GrahamGoudeau', given_name='Graham', family_name='Goudeau', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username=None, given_name='Silvina', family_name='Guidoni', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='colbych', given_name='Colby', family_name='Haggerty', orcid='0000-0002-2160-7288', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='raymonshansen', given_name='Raymon Skjørten', family_name='Hansen', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='pheuer', given_name='Peter', family_name='Heuer', orcid='0000-0001-5050-6606', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jhillairet', given_name='Julien', family_name='Hillairet', orcid='0000-0002-1073-6383', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='bucket420', given_name='Chris', family_name='Hoang', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='pohzipohzi', given_name='Poh Zi', family_name='How', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='yopology', given_name='Yi-Min', family_name='Huang', orcid='0000-0002-4237-2211', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='NabilHumphrey', given_name='Nabil', family_name='Humphrey', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='misupova', given_name='Maria', family_name='Isupova', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jeandet', given_name='Alexis', family_name='Jeandet', orcid='0000-0003-2892-6924', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='etjohnson', given_name='Elliot', family_name='Johnson', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jdkent', given_name='James', family_name='Kent', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='lemmatum', given_name='Pawel', family_name='Kozlowski', orcid='0000-0001-6849-3612', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='siddharthk07', given_name='Siddharth', family_name='Kulshrestha', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='kuszaj', given_name='Piotr', family_name='Kuszaj', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='alfkoehn', given_name='Alf', family_name='Köhn-Seemann', orcid='0000-0002-1192-2057', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='samurai688', given_name='Samuel', family_name='Langendorf', orcid='0000-0002-7757-5879', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='alanteriBW', given_name='Anna', family_name='Lanteri', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='tlee0818', given_name='Terrance Takho', family_name='Lee', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='SolarDrew', given_name='Drew', family_name='Leonard', orcid='0000-0001-5270-7487', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Quettle', given_name='Nicolas', family_name='Lequette', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='pllim', given_name='Pey Lian', family_name='Lim', orcid='0000-0003-0079-4114', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='adityamagarde', given_name='Aditya', family_name='Magarde', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='ritiek', given_name='Ritiek', family_name='Malhotra', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='JvPy', given_name='Joao Victor', family_name='Martinelli', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jota33', given_name='Isaias', family_name='McHardy', orcid='0000-0001-5394-9445', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Dhawal-Modi', given_name='Dhawal', family_name='Modi', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='kjmontes', given_name='Kevin', family_name='Montes', orcid='0000-0002-0762-3708', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Cadair', given_name='Stuart', family_name='Mumford', orcid='0000-0003-4217-4642', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='jams2', given_name='Joshua', family_name='Munn', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='LeoMurphyWM24', given_name='Leo', family_name='Murphy', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='namurphy', given_name='Nick', family_name='Murphy', orcid='0000-0001-6628-8033', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='suzannenie', given_name='Suzanne', family_name='Nie', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='mahimapannala', given_name='Mahima', family_name='Pannala', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='tulasinandan', given_name='Tulasi', family_name='Parashar', orcid='0000-0003-0602-8381', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='ministrike3', given_name='Neil', family_name='Patel', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='silvafrancisco', given_name='Francisco Silva', family_name='Pavon', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username=None, given_name='Jakub', family_name='Polak', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='RoberTnf', given_name='Roberto Díaz', family_name='Pérez', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='qudsiramiz', given_name='Ramiz', family_name='Qudsi', orcid='0000-0001-8358-0482', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='raajitr', given_name='Raajit', family_name='Raj', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='DarkAEther', given_name='Vishwas', family_name='Rajashekar', orcid='0000-0002-4914-6612', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='thecasuist', given_name='Afzal', family_name='Rao', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='arichar6', given_name='Steve', family_name='Richardson', orcid='0000-0002-3056-6334', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='diego7319', given_name='Diego A. Diaz', family_name='Riega', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='aksalcido', given_name='Armando', family_name='Salcido', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='savcheva', given_name='Antonia', family_name='Savcheva', orcid='0000-0002-5598-046X', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='ionizationcalc', given_name='Chengcai', family_name='Shen', orcid='0000-0002-9258-4490', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='andrewsheng2', given_name='Andrew', family_name='Sheng', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='nurbu5', given_name='Dawa Nurbu', family_name='Sherpa', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='lucianogsilvestri', given_name='Luciano', family_name='Silvestri', orcid='0000-0003-3530-7910', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='singha95', given_name='Angad', family_name='Singh', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Griffintaur', given_name='Ankit', family_name='Singh', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='bsipocz', given_name='Brigitta', family_name='Sipőcz', orcid='0000-0002-3713-6337', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='cskinner74', given_name='Cody', family_name='Skinner', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Nismirno', given_name='Nikita', family_name='Smirnov', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='dstansby', given_name='David', family_name='Stansby', orcid='0000-0002-1365-1908', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='StanczakDominik', given_name='Dominik', family_name='Stańczak', orcid='0000-0001-6291-8843', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='14tstinson', given_name='Tomás', family_name='Stinson', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='antoinetavant', given_name='Antoine', family_name='Tavant', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='Elfhelm', given_name='Thomas', family_name='Ulrich', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='tvarnish', given_name='Thomas', family_name='Varnish', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='tien-vo', given_name='Tien', family_name='Vo', orcid='0000-0002-8335-1441', affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='hzxusx', given_name='Sixue', family_name='Xu', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='syip1', given_name='Chun Hei', family_name='Yip', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='userr2232', given_name='Reynaldo Rojas', family_name='Zelaya', orcid=None, affiliation=None, on_coordinating_committee=False),
#  Contributor(github_username='carolyz', given_name='Carol', family_name='Zhang', orcid=None, affiliation=None, on_coordinating_committee=False)]
