# %% [markdown]
# # Geometry - equivalent centroid

# %%
from plasmapy.plasma.symbolicequilibrium import SymbolicEquilibrium

params = {"aspect_ratio": 0.32, "A": -0.155, "elongation": 1.7, "triangularity": 0.33}
eq = SymbolicEquilibrium(**params, B0=5.2, config="single-null")

ax = eq.plot()
fs = flux_surface = eq.get_flux_surface(-0.01)
fs.plot(ax, n=True);
centroid = np.array([np.mean(fs.R), np.mean(fs.Z)])
plt.plot(*centroid, "ro", label="Centroid")
plt.legend()

# %%
centroid[0] * 2 * np.pi * u.rad
# Out:
# <Quantity 6.31496366 rad>

# %%
from astropy import constants

# %%
toroid_area = centroid[0] * 2 * np.pi * fs.Lp
# Out:
# 14.289840142564467

# %%
np.sqrt(np.sum(fs.dL ** 2))
# Out:
# 0.13816160007407832

# %%
centroid
# Out:
# array([1.00505768, 0.0343478 ])

# %%
np.mean(fs.R)
# Out:
# 1.0050576827158

# %%
np.mean(fs.Z)
# Out:
# 0.03434780314551874

# %%
equiv_circle_radius = fs.Lp / 2 / np.pi
# Out:
# 0.3601443833034797

# %%
circle_angle = np.linspace(0, 2 * np.pi, 100);
circle_x = equiv_circle_radius * np.cos(circle_angle)
circle_y = equiv_circle_radius * np.sin(circle_angle)
# Out:
# array([ 0.00000000e+00,  2.28417684e-02,  4.55915611e-02,  6.81577727e-02,
#         9.04495370e-02,  1.12377093e-01,  1.33852146e-01,  1.54788224e-01,
#         1.75101024e-01,  1.94708754e-01,  2.13532460e-01,  2.31496347e-01,
#         2.48528080e-01,  2.64559078e-01,  2.79524790e-01,  2.93364954e-01,
#         3.06023841e-01,  3.17450478e-01,  3.27598854e-01,  3.36428105e-01,
#         3.43902679e-01,  3.49992478e-01,  3.54672981e-01,  3.57925341e-01,
#         3.59736462e-01,  3.60099051e-01,  3.59011649e-01,  3.56478633e-01,
#         3.52510203e-01,  3.47122340e-01,  3.40336737e-01,  3.32180718e-01,
#         3.22687125e-01,  3.11894185e-01,  2.99845357e-01,  2.86589157e-01,
#         2.72178964e-01,  2.56672803e-01,  2.40133110e-01,  2.22626487e-01,
#         2.04223425e-01,  1.84998027e-01,  1.65027708e-01,  1.44392880e-01,
#         1.23176634e-01,  1.01464398e-01,  7.93436010e-02,  5.69033153e-02,
#         3.42339001e-02,  1.14266370e-02, -1.14266370e-02, -3.42339001e-02,
#        -5.69033153e-02, -7.93436010e-02, -1.01464398e-01, -1.23176634e-01,
#        -1.44392880e-01, -1.65027708e-01, -1.84998027e-01, -2.04223425e-01,
#        -2.22626487e-01, -2.40133110e-01, -2.56672803e-01, -2.72178964e-01,
#        -2.86589157e-01, -2.99845357e-01, -3.11894185e-01, -3.22687125e-01,
#        -3.32180718e-01, -3.40336737e-01, -3.47122340e-01, -3.52510203e-01,
#        -3.56478633e-01, -3.59011649e-01, -3.60099051e-01, -3.59736462e-01,
#        -3.57925341e-01, -3.54672981e-01, -3.49992478e-01, -3.43902679e-01,
#        -3.36428105e-01, -3.27598854e-01, -3.17450478e-01, -3.06023841e-01,
#        -2.93364954e-01, -2.79524790e-01, -2.64559078e-01, -2.48528080e-01,
#        -2.31496347e-01, -2.13532460e-01, -1.94708754e-01, -1.75101024e-01,
#        -1.54788224e-01, -1.33852146e-01, -1.12377093e-01, -9.04495370e-02,
#        -6.81577727e-02, -4.55915611e-02, -2.28417684e-02, -8.82099332e-17])

# %%
ax = eq.plot()
fs.plot(ax, n=True);
centroid = np.array([np.mean(fs.R), np.mean(fs.Z)])
plt.plot(*centroid, "ro", label="Centroid")
plt.plot(circle_x + centroid[0], circle_y + centroid[1], label = "Equivalent circle")
plt.legend()
